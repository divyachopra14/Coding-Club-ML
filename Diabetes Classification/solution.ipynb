# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
x_train = pd.read_csv('./Training Data/Diabetes_XTrain.csv')
y_train = pd.read_csv('./Training Data/Diabetes_YTrain.csv')

# %%
x=x_train.values
y=y_train.values
y.reshape((-1))
print(x.shape)
print(y.shape)
n= x_train.nunique(axis=0)
n
# Out:
# (576, 8)
# (576, 1)
# Pregnancies                  16
# Glucose                     130
# BloodPressure                46
# SkinThickness                49
# Insulin                     161
# BMI                         224
# DiabetesPedigreeFunction    429
# Age                          52
# dtype: int64

# %%
label_x = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness',
'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']
label_y = []
i=0
for i in range(8):
    label_y.append(n[i])
plt.scatter(label_x,label_y)

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=5)
model.fit(x,y)
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:200: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier()

# %%
test_data = pd.read_csv('./Testing Data/Diabetes_XTest.csv')
test_data = np.asarray(test_data)

# %%
model.predict(test_data)
test_data[0]
# Out:
# array([  0.   , 180.   ,  90.   ,  26.   ,  90.   ,  36.5  ,   0.314,
#         35.   ])

# %%
model.score(x,y)
# Out:
# 0.7899305555555556

# %%
values = [  0.   , 180.   ,  90.   ,  26.   ,  90.   ,  36.5  ,   0.314,
        35.   ]
values = np.asarray(values)
pred = model.predict(values.reshape((1,-1)))
pred
# Out:
# array([1], dtype=int64)

# %%
plt.figure(0)
plt.scatter(x[:,0],y,label='f1')
plt.show()
plt.scatter(x[:,1],y,color='r',marker='^',label='f2')
plt.show()
plt.scatter(x[:,2],y,color='g',marker='>',label='f3')
plt.show()
plt.scatter(x[:,3],y,color='k',marker='+',label='f4')
plt.show()
plt.scatter(x[:,4],y,color='c', marker='v',label='f5')
plt.show()
plt.scatter(x[:,5],y,color='m',marker='|',label='f6')
plt.show()
plt.scatter(x[:,6],y,color='w',marker='D',label='f7')
plt.show()
plt.scatter(x[:,7],y,color='r',marker=',',label='f8')
plt.show()
plt.xlabel('x1')
plt.ylabel('x2')
# plt.legend()
# plt.show()
# Out:
# Text(0, 0.5, 'x2')
